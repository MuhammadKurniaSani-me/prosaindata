# %% [markdown]
# # 📚 Proyek Sains Data
#
# > Indented block
#
#
#
#
# ## Apa itu proyek sains data 🔎❓
#
#
# * ➡️  Metode mengambil, membersihkan, memproses data untuk diolah menjadi sebuah informasi yang bermanfaat
# * ➡️  Mata kuliah yang mempelajari proses pengelolahan data mentah menjadi data jadi dengan algoritma tertentu
# * ➡️  Proyek Sains Data dapat digunakan untuk melakukan klasifikasi data dengan algoritma yang tepat
#
#
# ### Data Mata Kuliah
#
#
# *  Nama: Proyek Sains Data IF6 B
# *  Program Studi : Informatika
# *  Mata Kuliah **Wajib**
