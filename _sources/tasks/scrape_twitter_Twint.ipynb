# %% [markdown]
# # Scrapping Twitter with Twint
#
#
# *   Get all data from Twitter
# *   Use Twint

# %%
### Data Wrangling 
import pandas as pd

# %%
# !pip uninstall Twint -y
# Out:
# WARNING: Skipping Twint as it is not installed.

# %%
# # instal Twint 
# !pip install Twint
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# !pip install nest_asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.6/653.6 kB 51.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.9/387.9 kB 34.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 5.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 2.1 MB/s eta 0:00:00
# ...

# %%
"""
Info Library Twint 

"This repository has been archived by the owner on Mar 30, 2023. It is now read-only."

Cara menggunakan 

Jika error -> "[ERROR] twint.token.RefreshTokenException: Could not find the Guest token in HTML"
referensi "https://github.com/twintproject/twint/issues/1061"

Jika error -> "CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value"
referensi "https://github.com/twintproject/twint/issues/951"
"""

import twint
import nest_asyncio 
nest_asyncio.apply()

c = twint.Config()
c.Limit = 500
# c.Search = "Puan Maharani" # topic Puan Maharani
c.Search = "#capres2024" # topic
c.Pandas = True
c.Store_csv = True
twint.run.Search(c)
Tweets_df = twint.storage.panda.Tweets_df

# %% [markdown]
# ```
# Index([
#     'id', 'conversation_id', 'created_at', 'date', 'timezone', 'place',
#        'tweet', 'language', 'hashtags', 'cashtags', 'user_id', 'user_id_str',
#        'username', 'name', 'day', 'hour', 'link', 'urls', 'photos', 'video',
#        'thumbnail', 'retweet', 'nlikes', 'nreplies', 'nretweets', 'quote_url',
#        'search', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')
# ```

# %%
df = pd.DataFrame(Tweets_df, columns=["username", "name", "tweet"])

# %%
import os
os.makedirs('/content/asset')
df.to_csv('/content/asset/tweets.csv')

# %%
pd.read_csv('/content/asset/tweets.csv')
# Out:
#      Unnamed: 0         username                       name  \
# 0             0        folktrade                Petrichor🌧️
# 1             1  Muhamma43425577               #PISANGrebus
# 2             2    dicaprio_deni              Deni Dicaprio
# 3             3         iniandii         𝕴𝖓𝖎𝖆𝖓𝖉𝖎𝖎 ´༎ຶ ۝ ༎ຶ༽
# 4             4         sospolkw               Rezim Buzzer
# ..          ...              ...                        ...
# 132         132         PUANnews  Berita Mbak Puan Maharani
# 133         133         PUANnews  Berita Mbak Puan Maharani
# 134         134         PUANnews  Berita Mbak Puan Maharani
# 135         135         PUANnews  Berita Mbak Puan Maharani
# 136         136     JarnasABWBpn      JARNAS ABW BALIKPAPAN
#
#                                                  tweet
# 0    @ndahmutty @AikHoki @maulanarifki @PNS_Ababil ...
# 1    @andre_rosiade Yakin : Capres 1. Puan Maharani...
# 2    @puanmaharani_ri Mbak @puanmaharani_ri for 202...
# ...
