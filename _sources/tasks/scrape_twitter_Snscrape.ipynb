# %% [markdown]
# # Scrapping Twitter with Snscrape
#
#
# *   Get all data from Twitter
# *   User Snscrape Library

# %%
### Data Wrangling 
import pandas as pd

# %%
# instal Snscrape 
# !pip3 install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snscrape in /usr/local/lib/python3.8/dist-packages (0.5.0.20230113)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Created a list to append all tweet attributes(data)
attributes_container = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('puan maharani').get_items()):
    if i>150:
        break
    attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(attributes_container, columns=["User", "Date Created", "Number of Likes", "Source of Tweet", "Tweet"])
# Out:
# <ipython-input-5-e8c0b5f6b65b>:11: FutureWarning: content is deprecated, use rawContent instead
#   attributes_container.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.sourceLabel, tweet.content])

# %%
tweets_df
# Out:
#                 User              Date Created  Number of Likes  \
# 0          RosiKamel 2023-02-21 10:17:22+00:00                0
# 1           iTeam_P4 2023-02-21 10:15:14+00:00                0
# 2       marufali6797 2023-02-21 10:09:37+00:00                0
# 3    martin_rachmant 2023-02-21 10:04:53+00:00                0
# 4          hambarokp 2023-02-21 10:04:22+00:00                1
# ..               ...                       ...              ...
# 146    BellaB6225355 2023-02-21 04:01:12+00:00                0
# 147        tri910721 2023-02-21 03:59:44+00:00                1
# 148        tri910721 2023-02-21 03:58:05+00:00                0
# 149        tri910721 2023-02-21 03:56:41+00:00                0
# 150        tri910721 2023-02-21 03:55:39+00:00                0
#
#          Source of Tweet                                              Tweet
# 0    Twitter for Android       @lovelands_ @ChaUnk_VR1 @puanmaharani_ri 😂😂😂
# 1     Twitter for iPhone  @lovelands_ @ChaUnk_VR1 @puanmaharani_ri Hah 🤦...
# 2    Twitter for Android                          @puanmaharani_ri Mantap,,
# 3     Twitter for iPhone  https://t.co/S3SsWjb1Z0 @KPK_RI @KejaksaanRI @...
# 4        Twitter Web App         @puanmaharani_ri Sebentar lagi kita puasa.
# ..                   ...                                                ...
# 146  Twitter for Android  @puanmaharani_ri Ikut bangga sebagai warga neg...
# 147  Twitter for Android      @PutraPujangga91 @puanmaharani_ri Siap dukung
# 148  Twitter for Android  @Ernasusi13 @puanmaharani_ri Semangat timnas I...
# 149  Twitter for Android  @Zia1111 @spiritcarrie5on @puanmaharani_ri @Mi...
# 150  Twitter for Android  @TominHino @annisaratna0 @puanmaharani_ri Past...
#
# [151 rows x 5 columns]
