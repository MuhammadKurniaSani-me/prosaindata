# %% [markdown]
# # Scrape Website with Beautiful Soap
#
# *   Use BeautifulSoup Library
# *   Main goal is to scrape data from Media Indonesia
# *   Target data likes 'sport news'

# %%
import pandas as pd
# !pip install requests
# !pip install html5lib
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests) (2022.12.7)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: html5lib in /usr/local/lib/python3.9/dist-packages (1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib) (0.5.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from bs4) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->bs4) (2.4.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1270 sha256=459e689a9c198692893146876afdb1413b1f9c6f45a22e6131b72aa25544a691
#   Stored in directory: /root/.cache/pip/wheels/73/2b/cb/099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1

# %%
# import library
from bs4 import BeautifulSoup
import requests

# %%
def request_url(url):
    return requests.get(url)

def request_header_url(header, url_website):
    headers = {'User-Agent': header}
    return requests.get(url=url_website, headers=headers)

def parse_website(request):
    """Use html5lib library to parse"""
    return BeautifulSoup(request.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib    

def prettify_web_structure(parsed_page):
    parsed_page.prettify()

def get_content_table(web_element, tag, attributes):
    return web_element.find(tag, attrs = attributes)

# %%
r = request_header_url("Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1", "https://mediaindonesia.com/sepak-bola")
soup = parse_website(r)
prettify_web_structure(soup)
table = get_content_table(soup, "ul", {'class':'article-block'})

# %%
articles = []
for row in table.findAll('a', attrs = {'class':'hover-effect'}):
	current_title = row["title"]

	r_row = request_header_url("Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1", row["href"])
	soup_row = parse_website(r_row)
	prettify_web_structure(soup_row)
	table_row = get_content_table(soup_row, "div", {"style":"line-height: 1.6;", "itemprop":"articleBody"})

	current_content = ""
	for inner_row in table_row.findAll('p'):
		current_content += f" {inner_row.string}"
	# dump variable 
	articles.append([current_title, current_content])
	print(f"sedang mengambil konten dengan judul '{current_title}...'")
	print()
# Out:
# sedang mengambil konten dengan judul 'Kemampuan Real Madrid akan Diuji di Markas Manchester City...'
#
# sedang mengambil konten dengan judul 'Bali United Fokus Benahi Benteng Pertahanan...'
#
# sedang mengambil konten dengan judul 'Manchester City Bisa Langsung Angkat Trofi usai Laga Melawan Chelsea...'
#
# sedang mengambil konten dengan judul 'Pelatih PSS Sambut Positif Regulasi Baru Liga 1...'
#
# sedang mengambil konten dengan judul 'Bielsa Ditunjuk Sebagai Pelatih Timnas Uruguay...'
#
# sedang mengambil konten dengan judul 'Klopp Sebut Kemenangan Liverpool Atas Leicester Sangat Penting...'
#
# sedang mengambil konten dengan judul 'Komisi X Sebut Erick Thohir Bawa Perubahan Positif Bagi PSSI dan Timnas...'
#
# sedang mengambil konten dengan judul 'Timnas U-22 akan Berjuang Maksimal di Laga Final SEA Games 2023...'
#
# sedang mengambil konten dengan judul 'Makam Pele yang Berlapis Emas Dibuka untuk Umum ...'
#
# sedang mengambil konten dengan judul 'Keluarga Beri Dukungan untuk Witan dari Kampung Halaman...'
#
# sedang mengambil konten dengan judul 'Tolak Pakai Jersey Pelangi, Mohamed Didenda Nantes...'
#
# sedang mengambil konten dengan judul 'Cardiff Gugat Nantes Terkait Pembelian Sala...'
#
# sedang mengambil konten dengan judul 'Tekuk Leicester, Liverpool Pertahankan Peluang Finis Empat Besar...'
#
# sedang mengambil konten dengan judul 'Barcelona Gelar Parade Juara...'
#
# sedang mengambil konten dengan judul 'Jangan Kendurkan Mental Garuda Muda...'
#
# sedang mengambil konten dengan judul 'Format Baru Liga 1 Disosialisasikan, ada VAR hingga Kuota Pemain Asing...'
#
# sedang mengambil konten dengan judul 'Titik Balik Inter Milan di Eropa Lewat Liga Champions Eropa...'
#
# sedang mengambil konten dengan judul 'Guardiola Puji Gundogan Usai Laga Kontra Everton...'
#
# sedang mengambil konten dengan judul 'Usai Antar Barcelona Juara La Liga, Busquets Ingin Hengkang...'
#
# sedang mengambil konten dengan judul 'Barcelona Juara La Liga, Laporta Puji Xavi...'

# %%
df = pd.DataFrame(articles, columns=["Judul", "Isi"])

# %%
import os 
os.makedirs('/content/asset')
df.to_csv('/content/asset/news_media_indonesia_sepak_bola.csv')

# %%
pd.read_csv('/content/asset/news_media_indonesia_sepak_bola.csv')
# Out:
#     Unnamed: 0                                              Judul  \
# 0            0  Kemampuan Real Madrid akan Diuji di Markas Man...
# 1            1        Bali United Fokus Benahi Benteng Pertahanan
# 2            2  Manchester City Bisa Langsung Angkat Trofi usa...
# 3            3    Pelatih PSS Sambut Positif Regulasi Baru Liga 1
# 4            4     Bielsa Ditunjuk Sebagai Pelatih Timnas Uruguay
# 5            5  Klopp Sebut Kemenangan Liverpool Atas Leiceste...
# 6            6  Komisi X Sebut Erick Thohir Bawa Perubahan Pos...
# 7            7  Timnas U-22 akan Berjuang Maksimal di Laga Fin...
# 8            8   Makam Pele yang Berlapis Emas Dibuka untuk Umum
# 9            9  Keluarga Beri Dukungan untuk Witan dari Kampun...
# 10          10  Tolak Pakai Jersey Pelangi, Mohamed Didenda Na...
# 11          11        Cardiff Gugat Nantes Terkait Pembelian Sala
# 12          12  Tekuk Leicester, Liverpool Pertahankan Peluang...
# 13          13                       Barcelona Gelar Parade Juara
# 14          14                Jangan Kendurkan Mental Garuda Muda
# 15          15  Format Baru Liga 1 Disosialisasikan, ada VAR h...
# 16          16  Titik Balik Inter Milan di Eropa Lewat Liga Ch...
# 17          17   Guardiola Puji Gundogan Usai Laga Kontra Everton
# 18          18  Usai Antar Barcelona Juara La Liga, Busquets I...
# 19          19         Barcelona Juara La Liga, Laporta Puji Xavi
#
#                                                   Isi
# 0    None None Man City memiliki rekor kandang yan...
# 1    BALI United fokus memperbaiki penampilan para...
# 2    None Piala akan dipersiapkan di sana dan tim ...
# 3    PELATIH kepala baru PSS Marian Mihail menyamb...
# 4    None Bielsa, yang dipecat Leeds United, Febru...
# 5    None Liverpool unggul dua gol lebih dulu mela...
# 6    None Anggota Komisi X DPR RI Dewi Coryati men...
# 7    None Kini, empat tahun berselang, timnas akan...
# 8    None Para pengunjung akan disambut oleh dua p...
# 9    JELANG final sepak bola di SEA Games 2023 yan...
# 10   None Nantes mengatakan Mohamed diganjar hukum...
# 11   None Kuasa hukum Nantes, Senin (15/5), mengat...
# 12   None Bagi Leicester, kekalahan itu membuat me...
# 13   None El Barce mangalahkan Espanyol, Senin (15...
# 14   None Kemenangan atas juara bertahan edisi 201...
# 15   None Kompetisi musim 2023-2024 akan digelar p...
# 16   None Inter mengawali kompetisi kasta tertingg...
# 17   None Dalam laga lanjutan Liga Primer Inggris ...
# 18   None Pemain berusia 34 tahun itu bakal mengak...
# 19   None "Xavi sangat menentukan. Pengetahuannya ...
