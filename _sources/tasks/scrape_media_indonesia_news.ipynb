# %% [markdown]
# # Scrape Website with Beautiful Soap
#
# *   Use BeautifulSoup Library
# *   Main goal is to scrape data from Media Indonesia
# *   Target data likes 'sport news'

# %%
import pandas as pd
# !pip install requests
# !pip install html5lib
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: html5lib in /usr/local/lib/python3.8/dist-packages (1.0.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.8/dist-packages (from html5lib) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.8/dist-packages (from html5lib) (0.5.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: bs4 in /usr/local/lib/python3.8/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from bs4) (4.6.3)

# %%
# import library
from bs4 import BeautifulSoup
import requests

# %%
def request_url(url):
    return requests.get(url)

def request_header_url(header, url_website):
    headers = {'User-Agent': header}
    return requests.get(url=url_website, headers=headers)

def parse_website(request):
    """Use html5lib library to parse"""
    return BeautifulSoup(request.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib    

def prettify_web_structure(parsed_page):
    parsed_page.prettify()

def get_content_table(web_element, tag, attributes):
    return web_element.find(tag, attrs = attributes)

# %%
r = request_header_url("Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1", "https://mediaindonesia.com/sepak-bola")
soup = parse_website(r)
prettify_web_structure(soup)
table = get_content_table(soup, "ul", {'class':'article-block'})

# %%
articles = []
for row in table.findAll('a', attrs = {'class':'hover-effect'}):
	current_title = row["title"]

	r_row = request_header_url("Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1", row["href"])
	soup_row = parse_website(r_row)
	prettify_web_structure(soup_row)
	table_row = get_content_table(soup_row, "div", {"style":"line-height: 1.6;", "itemprop":"articleBody"})

	current_content = ""
	for inner_row in table_row.findAll('p'):
		current_content += f" {inner_row.string}"
	# dump variable 
	articles.append([current_title, current_content])
	print(f"sedang mengambil konten dengan judul '{current_title}...'")
	print()
# Out:
# sedang mengambil konten dengan judul 'PSG Terancam Kehilangan Neymar Saat Dijamu Bayern Muenchen...'
#
# sedang mengambil konten dengan judul 'Terhindar dari Skors, Nagelsmann hanya Didenda Rp808 Juta...'
#
# sedang mengambil konten dengan judul 'PSM Makassar Waspadai Kekuatan Persebaya...'
#
# sedang mengambil konten dengan judul 'Persija Terus Bayangi PSM...'
#
# sedang mengambil konten dengan judul 'Liverpool Dihancurkan Madrid, van Dijk: Kami Bukan Robot ...'
#
# sedang mengambil konten dengan judul 'Xavi tanpa Duet Pedri-Gavi saat Tandang ke Old Trafford...'
#
# sedang mengambil konten dengan judul 'Menpora: Naturalisasi Pemain U-20 Tunggu Masa Reses DPR...'
#
# sedang mengambil konten dengan judul 'Jamu Porto, Kemenangan Jadi Hal Wajib Bagi Inter Milan ...'
#
# sedang mengambil konten dengan judul 'Shin Tae-yong Harap Mental Tim U-20 Terasah di Piala Asia...'
#
# sedang mengambil konten dengan judul 'Napoli Maju Satu Langkah Menuju Perempat Final Liga Champions...'
#
# sedang mengambil konten dengan judul 'Ancelotti Emoh Jemawa Usai Madrid Permalukan Liverpool...'
#
# sedang mengambil konten dengan judul 'PSG: Neymar Mengalami Robek Ligamen di Pergelangan Kaki...'
#
# sedang mengambil konten dengan judul 'Menpora Berharap Mini Turnamen jadi Bekal Timnas U-20 di Piala Asia...'
#
# sedang mengambil konten dengan judul 'Tuchel Berpeluang Kembali Ke PSG...'
#
# sedang mengambil konten dengan judul 'Khawatir Kabur, Penahanan Dani Alves Diperpanjang...'
#
# sedang mengambil konten dengan judul 'Javi Gracia Pelatih Baru Leeds United...'
#
# sedang mengambil konten dengan judul 'Inzagi  Ingin Akhiri Mimpi Buruk Tim Italia Melawan Porto...'
#
# sedang mengambil konten dengan judul 'Tanpa 3 Pemain Asing, Macan Kemayoran Yakin Kalahkan Barito...'
#
# sedang mengambil konten dengan judul 'Dortmund Berharap Bellingham Mau Perpanjang Kontrak...'
#
# sedang mengambil konten dengan judul 'Jaminan Ditolak Pengadilan, Dani Alves Tetap Mendekam Di Penjara...'

# %%
df = pd.DataFrame(articles, columns=["Judul", "Isi"])

# %%
import os  
df.to_csv('/content/drive/MyDrive/prosaindata/source/tasks/output/news_media_indonesia_sepak_bola.csv')

# %%
pd.read_csv('/content/drive/MyDrive/prosaindata/source/tasks/output/tweets.csv')
# Out:
#      Unnamed: 0         username                       name  \
# 0             0        folktrade                Petrichor🌧️
# 1             1  Muhamma43425577               #PISANGrebus
# 2             2    dicaprio_deni              Deni Dicaprio
# 3             3         iniandii         𝕴𝖓𝖎𝖆𝖓𝖉𝖎𝖎 ´༎ຶ ۝ ༎ຶ༽
# 4             4         sospolkw               Rezim Buzzer
# ..          ...              ...                        ...
# 132         132         PUANnews  Berita Mbak Puan Maharani
# 133         133         PUANnews  Berita Mbak Puan Maharani
# 134         134         PUANnews  Berita Mbak Puan Maharani
# 135         135         PUANnews  Berita Mbak Puan Maharani
# 136         136     JarnasABWBpn      JARNAS ABW BALIKPAPAN
#
#                                                  tweet
# 0    @ndahmutty @AikHoki @maulanarifki @PNS_Ababil ...
# 1    @andre_rosiade Yakin : Capres 1. Puan Maharani...
# 2    @puanmaharani_ri Mbak @puanmaharani_ri for 202...
# 3    @hanmula @kring_pajak @KPK_RI @BBCIndonesia @j...
# 4    @StopPlandemit Yth buk @puanmaharani_ri  apa a...
# ..                                                 ...
# 132  #GPMN Galang Dukungan Puan Maharani di Desa - ...
# 133  #Untuk Raih Kemenangan pada 2024, Puan-Airlang...
# 134  #Jokowi Sebut Banyak Capres, Adi Prayitno: Nun...
# 135  #Polisi Duga Kebakaran Pasar Cik Puan akibat K...
# 136  Survey Capres Favorit Kaltim, yuk yg domisili ...
#
# [137 rows x 4 columns]
