# %%
import pandas as pd
import numpy as np
from numpy import array


#for text pre-processing
import re, string
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# stemming for Indonesian Language
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

nltk.download('punkt')
nltk.download('stopwords')


#for model-building
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler  # to standardize the features
from sklearn.decomposition import PCA  # to apply PCA
import seaborn as sns  # to plot the heat maps


#for word embedding
import gensim
from gensim.models import Word2Vec

# # for NLP use BERT
# from sentence_transformers import SentenceTransformer
# import spacy_sentence_bert

# import warnings
# warnings.filterwarnings(action = 'ignore')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
data_xls = pd.read_excel("/content/drive/MyDrive/prosaindata/source/tasks/assets/vicinitas_search_results.xlsx")

# %%
import os  
data_xls.to_csv('/content/drive/MyDrive/prosaindata/source/tasks/assets/tweets_capres_2024.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/prosaindata/source/tasks/assets/tweets_capres_2024.csv')

# %%
df.head()
# Out:
#    Unnamed: 0             Tweet Id  \
# 0           0  1655563456026939392
# 1           1  1655563374498029569
# 2           2  1655563270915493888
# 3           3  1655563193262161924
# 4           4  1655563102942007296
#
#                                                 Text                 Name  \
# 0  RT @Ganjaran_app : Membakar semangat ribuan ka...         Ujang_Lanang
# 1  RT @Ganjaran_app : Membakar semangat ribuan ka...          Bayu_Styles
# 2  RT @Ganjaran_app : Membakar semangat ribuan ka...  Markowsiego_maulana
# 3  RT @Ganjaran_app : Membakar semangat ribuan ka...       Nanang_sulivan
# 4  RT @Ganjaran_app : Membakar semangat ribuan ka...           Rizki_Maul
#
#      Screen Name                       UTC                      Created At  \
# 0   UjangLanang8  2023-05-08T13:21:01.000Z  Mon May 08 13:21:01 +0000 2023
# 1     StylesBayu  2023-05-08T13:20:42.000Z  Mon May 08 13:20:42 +0000 2023
# 2   Markowsiego_  2023-05-08T13:20:17.000Z  Mon May 08 13:20:17 +0000 2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1864 entries, 0 to 1863
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1864 non-null   int64
#  1   Tweet Id     1864 non-null   int64
#  2   Text         1864 non-null   object
#  3   Name         1864 non-null   object
#  4   Screen Name  1864 non-null   object
#  5   UTC          1864 non-null   object
#  6   Created At   1864 non-null   object
#  7   Favorites    1864 non-null   int64
#  8   Retweets     1864 non-null   int64
#  9   Language     1864 non-null   object
#  10  Client       1864 non-null   object
#  11  Tweet Type   1864 non-null   object
#  12  URLs         180 non-null    object
#  13  Hashtags     1864 non-null   int64
#  14  Mentions     1864 non-null   int64
#  15  Media Type   1568 non-null   object
#  16  Media URLs   1568 non-null   object
#  17  Unnamed: 16  74 non-null     object
# ...
